# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler, QuantileTransformer, RobustScaler
import copy


from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN


sns.set(font_scale=1.5)

# %% [markdown]
# # Functions

# %%
def create_dataset(x, y, time_steps=1, pred_time_steps=1, overlap=True):
    xs, ys = [], []
    if overlap:
        jump = 1
    else:
        jump = pred_time_steps
    for i in range(0, len(x) - time_steps - pred_time_steps + 1, jump):
        v = x[i:(i + time_steps), :]
        xs.append(v)
        ys.append(y[i + time_steps:i + time_steps + pred_time_steps])
    return np.array(xs), np.array(ys)

# %%
def make_RNN_model(input_shape, layers, dense_layers, activation, output, activation_out, rnn_layer='simple'):
    model = []
    ret_sequences = True
    if rnn_layer == 'lstm':
        layer = LSTM(units=layers[0], return_sequences=ret_sequences, input_shape=input_shape)
    elif rnn_layer == 'gru':
        layer = GRU(units=layers[0], return_sequences=ret_sequences, input_shape=input_shape)
    else:
        layer = SimpleRNN(units=layers[0], return_sequences=ret_sequences, input_shape=input_shape)

    model.append(layer)

    for i in range(1, len(layers)):
        if i == len(layers)-1:
            ret_sequences = False

        if rnn_layer == 'lstm':
            layer = LSTM(units=layers[i], return_sequences=ret_sequences)
        elif rnn_layer == 'gru':
            layer = GRU(units=layers[i], return_sequences=ret_sequences)
        else:
            layer = SimpleRNN(units=layers[i], return_sequences=ret_sequences)
        model.append(layer)

    for dl in dense_layers:
        model.append(tf.keras.layers.Dense(dl, activation=activation))

    model.append(tf.keras.layers.Dense(output, activation=activation_out))
    model = tf.keras.Sequential(model)

    return model

# %%
def train_RNN_network(train, test, val, layers, dense_layers, activation, output, activation_out, lags, epochs, batch_size, opt, loss, factor=0.8, patience_reduce=3, patience_early=5, rnn_layer='simple'):
    dict_results = {'Lags': [], 'MAE': [], 'RMSE': [], 'R2': []}
    for i in lags:
        x_train, y_train = create_dataset(train, train, i, output, True)
        x_val, y_val = create_dataset(val, val, i, output, False)
        x_test, y_test = create_dataset(test, test, i, output, False)

        model = make_RNN_model((i,1), layers, dense_layers, activation, output, activation_out, rnn_layer)

        opt_tmp = copy.copy(opt)
        model_tmp = tf.keras.models.clone_model(model)
        model_tmp.compile(optimizer=opt_tmp, loss=loss, metrics=['mae', 'mse'])
        reduce_lr = ReduceLROnPlateau(monitor='loss', factor=factor, patience=patience_reduce)
        early_stopping = EarlyStopping(monitor='val_loss', patience=patience_early, restore_best_weights=True)
        history = model_tmp.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=epochs, batch_size=batch_size, verbose=0, callbacks=[reduce_lr, early_stopping])

        y_pred = model_tmp.predict(x_test, verbose=0, batch_size=batch_size)
        y_pred = scaler.inverse_transform(y_pred).flatten()
        y_test = scaler.inverse_transform(y_test[:,:,0]).flatten()
        mae = mean_absolute_error(y_test, y_pred)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        dict_results['MAE'].append(mae)
        dict_results['RMSE'].append(rmse)
        dict_results['R2'].append(r2)
        dict_results['Lags'].append(i)

        print('MAE:', mae, 'RMSE:', rmse, 'and R2:', r2, 'for', i, 'lags')
    return pd.DataFrame(dict_results)

# %% [markdown]
# # About Dataset
# This dataset is the most up-to-date kaggle dataset about daily sunspot counts with no missing values. The source data originate from the World Data Center SILSO, Royal Observatory of Belgium, Brussels.
#
# The Daily total sunspot number is derived by the formula: R = Ns + 10 * Ng, with Ns the number of spots and Ng the number of groups counted over the entire solar disk. The original data contained some values between 1818 and 1850 but I removed those years because there was too much missing values.
#
#
# **Error values**
#
# Those values correspond to the standard deviation of raw numbers provided by all stations.
#
# * Before 1981, the errors are estimated with the help of an auto-regressive model based on the Poissonian distribution of actual Sunspot Numbers.
# * From 1981 onwards, the error value is the actual standard deviation of the sample of raw observations used to compute the daily value.
#
# **The standard error of the daily Sunspot Number can be computed by:**
#
# sigma/sqrt(N) where sigma is the listed standard deviation and N the number of observations for the day.
# Before 1981, the number of observations is set to 1, as the Sunspot Number was then essentially the raw Wolf number from the Zürich Observatory.
#
#
# **Columns Description**
#
# * Column 1-3: Gregorian calendar date
#     * Year
#     * Month
#     * Day
# * Column 4: Date in fraction of year
# *  Column 5: Daily total sunspot number. A value of -1 indicates that no number is available for that day (missing value): there should not be any missing values as I removed all years before 1850 where there was missing values.
# * Column 6: Daily standard deviation of the input sunspot numbers from individual stations.
# * Column 7: Number of observations used to compute the daily value.
# * Column 8: Definitive/provisional indicator. A blank (NaN) indicates that the value is definitive. A '*' symbol indicates that the value is still provisional and is subject to a possible revision (Usually the last 3 to 6 months)

# %% [markdown]
# # Preprocessing data

# %% [markdown]
# ## Read data

# %%
df = pd.read_csv('sunspots_1850_2024.csv')
df.head()
# Out:
#          date  year  month  day  date_frac  counts   std  nobs indicator
# 0  1850-01-01  1850      1    1   1850.001     253  19.6     1       NaN
# 1  1850-01-02  1850      1    2   1850.004     162  15.5     1       NaN
# 2  1850-01-03  1850      1    3   1850.007     217  18.1     1       NaN
# 3  1850-01-04  1850      1    4   1850.010      99  12.0     1       NaN
# 4  1850-01-05  1850      1    5   1850.012     108  12.6     1       NaN

# %% [markdown]
# ## Make dataset

# %%
df = pd.DataFrame(df.groupby(pd.PeriodIndex(df['date'], freq="D"))['counts'].mean())
df = df.reset_index()
df['date'] = df['date'].dt.to_timestamp('s').dt.strftime(r'%Y-%m-%d')
df = df.set_index('date')
df.head()
# Out:
#             counts
# date
# 1850-01-01   253.0
# 1850-01-02   162.0
# 1850-01-03   217.0
# 1850-01-04    99.0
# 1850-01-05   108.0

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## Plot sunspots monthly mean by time

# %%
plt.figure(figsize=(20,5))
ax = sns.lineplot(y=df['counts'], x=df.index)
ax.set_xticks(ax.get_xticks()[::1460])
plt.xticks(rotation=90)
# Out:
# (array([    0,  1460,  2920,  4380,  5840,  7300,  8760, 10220, 11680,
#         13140, 14600, 16060, 17520, 18980, 20440, 21900, 23360, 24820,
#         26280, 27740, 29200, 30660, 32120, 33580, 35040, 36500, 37960,
#         39420, 40880, 42340, 43800, 45260, 46720, 48180, 49640, 51100,
#         52560, 54020, 55480, 56940, 58400, 59860, 61320, 62780]),
#  [Text(0, 0, '1850-01-01'),
#   Text(1460, 0, '1853-12-31'),
#   Text(2920, 0, '1857-12-30'),
#   Text(4380, 0, '1861-12-29'),
#   Text(5840, 0, '1865-12-28'),
#   Text(7300, 0, '1869-12-27'),
#   Text(8760, 0, '1873-12-26'),
#   Text(10220, 0, '1877-12-25'),
#   Text(11680, 0, '1881-12-24'),
#   Text(13140, 0, '1885-12-23'),
#   Text(14600, 0, '1889-12-22'),
#   Text(16060, 0, '1893-12-21'),
#   Text(17520, 0, '1897-12-20'),
#   Text(18980, 0, '1901-12-20'),
#   Text(20440, 0, '1905-12-19'),
#   Text(21900, 0, '1909-12-18'),
#   Text(23360, 0, '1913-12-17'),
#   Text(24820, 0, '1917-12-16'),
#   Text(26280, 0, '1921-12-15'),
#   Text(27740, 0, '1925-12-14'),
#   Text(29200, 0, '1929-12-13'),
#   Text(30660, 0, '1933-12-12'),
#   Text(32120, 0, '1937-12-11'),
#   Text(33580, 0, '1941-12-10'),
#   Text(35040, 0, '1945-12-09'),
#   Text(36500, 0, '1949-12-08'),
#   Text(37960, 0, '1953-12-07'),
#   Text(39420, 0, '1957-12-06'),
#   Text(40880, 0, '1961-12-05'),
#   Text(42340, 0, '1965-12-04'),
#   Text(43800, 0, '1969-12-03'),
#   Text(45260, 0, '1973-12-02'),
#   Text(46720, 0, '1977-12-01'),
#   Text(48180, 0, '1981-11-30'),
#   Text(49640, 0, '1985-11-29'),
#   Text(51100, 0, '1989-11-28'),
#   Text(52560, 0, '1993-11-27'),
#   Text(54020, 0, '1997-11-26'),
#   Text(55480, 0, '2001-11-25'),
#   Text(56940, 0, '2005-11-24'),
#   Text(58400, 0, '2009-11-23'),
#   Text(59860, 0, '2013-11-22'),
#   Text(61320, 0, '2017-11-21'),
#   Text(62780, 0, '2021-11-20')])

# %%
df.describe()
# Out:
#              counts
# count  63673.000000
# mean      83.410174
# std       76.875804
# min        0.000000
# 25%       21.000000
# 50%       64.000000
# 75%      128.000000
# max      528.000000

# %% [markdown]
# # Prepare data

# %% [markdown]
# ## Scale data

# %%
scaler  = MinMaxScaler() # scaler
df_scaled = pd.DataFrame(scaler.fit_transform(df))
df_scaled = df_scaled.rename(columns = {0: 'value'})
df_scaled.head()
# Out:
#       value
# 0  0.479167
# 1  0.306818
# 2  0.410985
# 3  0.187500
# 4  0.204545

# %% [markdown]
# ## Split data

# %%
train_split = int(len(df) * 0.7)
val_split = int(len(df) * 0.1)

# %%
df_train = df_scaled[:train_split].to_numpy()
df_val = df_scaled[train_split:train_split+val_split].to_numpy()
df_test = df_scaled[train_split+val_split:].to_numpy()

# %% [markdown]
# # Train RNN

# %% [markdown]
# ## Simple RNN

# %%
opt = tf.keras.optimizers.Adam(learning_rate=1e-2)
scores = train_RNN_network(train=df_train, test=df_test, val=df_val, layers=[64,64], dense_layers=[32],
                           activation='relu', output=7, activation_out=None, lags=[7,15,30], epochs=30, batch_size=1024, opt=opt,
                           loss='mse', rnn_layer='simple')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 22.759972733183325 RMSE: 32.576347417977075 and R2: 0.7920229609454622 for 7 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 21.490062771329754 RMSE: 30.847602766549972 and R2: 0.8128683295525754 for 15 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a47048df490> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a47048df490> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MAE: 19.984048306735563 RMSE: 29.042944598811637 and R2: 0.8339878058124707 for 30 lags

# %%
sns.lineplot(data=scores, x='Lags', y='RMSE')
# Out:
# <Axes: xlabel='Lags', ylabel='RMSE'>

# %% [markdown]
# ## GRU

# %%
opt = tf.keras.optimizers.Adam(learning_rate=1e-2)
scores = train_RNN_network(train=df_train, test=df_test, val=df_val, layers=[64,64], dense_layers=[32],
                           activation='relu', output=7, activation_out=None, lags=[7,15,30,60,120,365], epochs=30, batch_size=1024, opt=opt,
                           loss='mse', rnn_layer='gru')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 23.264404883198107 RMSE: 32.92751845526302 and R2: 0.787514832960549 for 7 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 21.013917782535547 RMSE: 30.54629826729023 and R2: 0.816506100092832 for 15 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 19.795049692171382 RMSE: 28.745747864721324 and R2: 0.8373680307208407 for 30 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 19.973118707111905 RMSE: 28.84468728150585 and R2: 0.8342889384275837 for 60 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 19.394006545095337 RMSE: 27.842904502066787 and R2: 0.8425779097660997 for 120 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 19.081630968104974 RMSE: 27.523869503452556 and R2: 0.8371035715263185 for 365 lags

# %%
sns.lineplot(data=scores, x='Lags', y='RMSE')
# Out:
# <Axes: xlabel='Lags', ylabel='RMSE'>

# %% [markdown]
# ## LSTM

# %%
opt = tf.keras.optimizers.Adam(learning_rate=1e-2)
scores = train_RNN_network(train=df_train, test=df_test, val=df_val, layers=[64,64], dense_layers=[32],
                           activation='relu', output=7, activation_out=None, lags=[7,15,30,60,120,365], epochs=30, batch_size=1024, opt=opt,
                           loss='mse', rnn_layer='lstm')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 23.03957586929743 RMSE: 32.8211889459868 and R2: 0.7888849309962038 for 7 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 20.999646034374937 RMSE: 30.518340335540408 and R2: 0.8168418371554632 for 15 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 19.84660360115994 RMSE: 28.699571595485683 and R2: 0.8378901048676959 for 30 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 20.338100140618828 RMSE: 28.851752068577785 and R2: 0.8342077548999154 for 60 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 19.795991087755574 RMSE: 28.161409180900606 and R2: 0.8389556975165162 for 120 lags
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MAE: 19.363819354343207 RMSE: 27.868312209025206 and R2: 0.8330009822068226 for 365 lags

# %%
sns.lineplot(data=scores, x='Lags', y='RMSE')
# Out:
# <Axes: xlabel='Lags', ylabel='RMSE'>

# %% [markdown]
# # Select one model

# %%
time_steps = 120
pred_time_steps = 7
x_train, y_train = create_dataset(df_train, df_train, time_steps, pred_time_steps, True)
x_val, y_val = create_dataset(df_val, df_val, time_steps, pred_time_steps, True)
x_test, y_test = create_dataset(df_test, df_test, time_steps, pred_time_steps, False)

# %%
model = make_RNN_model(input_shape=(time_steps, 1), layers=[64,64], dense_layers=[32], activation='relu',
                       output=pred_time_steps, activation_out=None, rnn_layer='gru')
opt = tf.keras.optimizers.Adam(learning_rate=1e-2)
model.compile(optimizer=opt, loss='mse', metrics=['mae', 'mse'])
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.8, patience=5)
early_stopping = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=300, batch_size=1024, verbose=1, callbacks=[reduce_lr, early_stopping])
# Out:
# Epoch 1/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.0142 - mae: 0.0845 - mse: 0.0142 - val_loss: 0.0049 - val_mae: 0.0510 - val_mse: 0.0049 - learning_rate: 0.0100
# Epoch 2/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0054 - mae: 0.0532 - mse: 0.0054 - val_loss: 0.0040 - val_mae: 0.0456 - val_mse: 0.0040 - learning_rate: 0.0100
# Epoch 3/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0048 - mae: 0.0495 - mse: 0.0048 - val_loss: 0.0039 - val_mae: 0.0438 - val_mse: 0.0039 - learning_rate: 0.0100
# Epoch 4/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0047 - mae: 0.0485 - mse: 0.0047 - val_loss: 0.0039 - val_mae: 0.0436 - val_mse: 0.0039 - learning_rate: 0.0100
# Epoch 5/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0047 - mae: 0.0487 - mse: 0.0047 - val_loss: 0.0042 - val_mae: 0.0441 - val_mse: 0.0042 - learning_rate: 0.0100
# Epoch 6/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0049 - mae: 0.0493 - mse: 0.0049 - val_loss: 0.0041 - val_mae: 0.0478 - val_mse: 0.0041 - learning_rate: 0.0100
# Epoch 7/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0048 - mae: 0.0492 - mse: 0.0048 - val_loss: 0.0039 - val_mae: 0.0433 - val_mse: 0.0039 - learning_rate: 0.0100
# Epoch 8/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0046 - mae: 0.0481 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0447 - val_mse: 0.0039 - learning_rate: 0.0100
# Epoch 9/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0047 - mae: 0.0484 - mse: 0.0047 - val_loss: 0.0039 - val_mae: 0.0431 - val_mse: 0.0039 - learning_rate: 0.0100
# Epoch 10/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0048 - mae: 0.0495 - mse: 0.0048 - val_loss: 0.0040 - val_mae: 0.0456 - val_mse: 0.0040 - learning_rate: 0.0100
# Epoch 11/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0047 - mae: 0.0491 - mse: 0.0047 - val_loss: 0.0039 - val_mae: 0.0443 - val_mse: 0.0039 - learning_rate: 0.0100
# Epoch 12/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0047 - mae: 0.0486 - mse: 0.0047 - val_loss: 0.0039 - val_mae: 0.0433 - val_mse: 0.0039 - learning_rate: 0.0100
# Epoch 13/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0047 - mae: 0.0483 - mse: 0.0047 - val_loss: 0.0039 - val_mae: 0.0432 - val_mse: 0.0039 - learning_rate: 0.0080
# Epoch 14/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0046 - mae: 0.0479 - mse: 0.0046 - val_loss: 0.0040 - val_mae: 0.0435 - val_mse: 0.0040 - learning_rate: 0.0080
# Epoch 15/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0046 - mae: 0.0482 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0441 - val_mse: 0.0039 - learning_rate: 0.0080
# Epoch 16/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0046 - mae: 0.0481 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0436 - val_mse: 0.0039 - learning_rate: 0.0080
# Epoch 17/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0047 - mae: 0.0487 - mse: 0.0047 - val_loss: 0.0039 - val_mae: 0.0440 - val_mse: 0.0039 - learning_rate: 0.0080
# Epoch 18/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0046 - mae: 0.0478 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0434 - val_mse: 0.0039 - learning_rate: 0.0064
# Epoch 19/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0046 - mae: 0.0476 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0434 - val_mse: 0.0039 - learning_rate: 0.0064
# Epoch 20/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0046 - mae: 0.0481 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0431 - val_mse: 0.0039 - learning_rate: 0.0064
# Epoch 21/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0046 - mae: 0.0479 - mse: 0.0046 - val_loss: 0.0038 - val_mae: 0.0429 - val_mse: 0.0038 - learning_rate: 0.0064
# Epoch 22/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0046 - mae: 0.0478 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0430 - val_mse: 0.0039 - learning_rate: 0.0064
# Epoch 23/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0046 - mae: 0.0479 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0437 - val_mse: 0.0039 - learning_rate: 0.0051
# Epoch 24/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0046 - mae: 0.0477 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0432 - val_mse: 0.0039 - learning_rate: 0.0051
# Epoch 25/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0046 - mae: 0.0477 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0433 - val_mse: 0.0039 - learning_rate: 0.0051
# Epoch 26/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0045 - mae: 0.0475 - mse: 0.0045 - val_loss: 0.0039 - val_mae: 0.0432 - val_mse: 0.0039 - learning_rate: 0.0051
# Epoch 27/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0045 - mae: 0.0475 - mse: 0.0045 - val_loss: 0.0039 - val_mae: 0.0437 - val_mse: 0.0039 - learning_rate: 0.0051
# Epoch 28/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0045 - mae: 0.0476 - mse: 0.0045 - val_loss: 0.0039 - val_mae: 0.0433 - val_mse: 0.0039 - learning_rate: 0.0051
# Epoch 29/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0046 - mae: 0.0478 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0432 - val_mse: 0.0039 - learning_rate: 0.0041
# Epoch 30/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0045 - mae: 0.0476 - mse: 0.0045 - val_loss: 0.0039 - val_mae: 0.0434 - val_mse: 0.0039 - learning_rate: 0.0041
# Epoch 31/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0046 - mae: 0.0478 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0433 - val_mse: 0.0039 - learning_rate: 0.0041
# Epoch 32/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0045 - mae: 0.0475 - mse: 0.0045 - val_loss: 0.0040 - val_mae: 0.0435 - val_mse: 0.0040 - learning_rate: 0.0041
# Epoch 33/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0046 - mae: 0.0477 - mse: 0.0046 - val_loss: 0.0039 - val_mae: 0.0439 - val_mse: 0.0039 - learning_rate: 0.0041
# Epoch 34/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0044 - mae: 0.0473 - mse: 0.0044 - val_loss: 0.0039 - val_mae: 0.0441 - val_mse: 0.0039 - learning_rate: 0.0033
# Epoch 35/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0044 - mae: 0.0475 - mse: 0.0044 - val_loss: 0.0040 - val_mae: 0.0437 - val_mse: 0.0040 - learning_rate: 0.0033
# Epoch 36/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0044 - mae: 0.0471 - mse: 0.0044 - val_loss: 0.0039 - val_mae: 0.0435 - val_mse: 0.0039 - learning_rate: 0.0033
# Epoch 37/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0045 - mae: 0.0472 - mse: 0.0045 - val_loss: 0.0041 - val_mae: 0.0441 - val_mse: 0.0041 - learning_rate: 0.0033
# Epoch 38/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0044 - mae: 0.0471 - mse: 0.0044 - val_loss: 0.0041 - val_mae: 0.0441 - val_mse: 0.0041 - learning_rate: 0.0033
# Epoch 39/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0043 - mae: 0.0466 - mse: 0.0043 - val_loss: 0.0041 - val_mae: 0.0441 - val_mse: 0.0041 - learning_rate: 0.0033
# Epoch 40/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0044 - mae: 0.0474 - mse: 0.0044 - val_loss: 0.0042 - val_mae: 0.0444 - val_mse: 0.0042 - learning_rate: 0.0033
# Epoch 41/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0044 - mae: 0.0471 - mse: 0.0044 - val_loss: 0.0044 - val_mae: 0.0459 - val_mse: 0.0044 - learning_rate: 0.0033
# Epoch 42/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0044 - mae: 0.0473 - mse: 0.0044 - val_loss: 0.0042 - val_mae: 0.0444 - val_mse: 0.0042 - learning_rate: 0.0033
# Epoch 43/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0044 - mae: 0.0471 - mse: 0.0044 - val_loss: 0.0041 - val_mae: 0.0442 - val_mse: 0.0041 - learning_rate: 0.0026
# Epoch 44/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0044 - mae: 0.0469 - mse: 0.0044 - val_loss: 0.0042 - val_mae: 0.0446 - val_mse: 0.0042 - learning_rate: 0.0026
# Epoch 45/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0044 - mae: 0.0470 - mse: 0.0044 - val_loss: 0.0042 - val_mae: 0.0445 - val_mse: 0.0042 - learning_rate: 0.0026
# Epoch 46/300
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0043 - mae: 0.0468 - mse: 0.0043 - val_loss: 0.0044 - val_mae: 0.0449 - val_mse: 0.0044 - learning_rate: 0.0026

# %%
hist = {'loss': history.history['loss'], 'val_loss': history.history['val_loss']}
sns.lineplot(data=hist, palette='viridis')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.yscale('log')

# %% [markdown]
# ## Test results

# %%
y_pred = scaler.inverse_transform(model.predict(x_test)).flatten()
y_true = scaler.inverse_transform(y_test[:,:, 0]).flatten()
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %%
plt.figure(figsize=(24,6))
res = {'True': y_true, 'Pred': y_pred}
sns.lineplot(data=res, palette='viridis')
plt.ylabel('count')
print('MAE:', mean_absolute_error(y_true, y_pred), '\nRMSE:', np.sqrt(mean_squared_error(y_true, y_pred)), '\nR2:', r2_score(y_true, y_pred))
# Out:
# MAE: 19.36518049496695
# RMSE: 27.896165573974365
# R2: 0.8419750639925925
